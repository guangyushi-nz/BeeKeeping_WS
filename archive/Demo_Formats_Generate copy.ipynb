# %%
from pydub import silence, AudioSegment
from pathlib import Path


# !C:\\Python\\libs\\ffmpeg\\bin\\ffmpeg.exe -i QueenBee_Training_45mins.wav -b:a 64k QueenBee_Training_45mins_64K.mp3
# !C:\\Python\\libs\\ffmpeg\\bin\\ffmpeg.exe -i QueenBee_Testing_15mins.wav -b:a 64k QueenBee_Testing_15mins_64K.mp3
# !C:\\Python\\libs\\ffmpeg\\bin\\ffmpeg.exe -i No_QueenBee_Training_45mins.wav -b:a 64k No_QueenBee_Training_45mins_64K.mp3
# !C:\\Python\\libs\\ffmpeg\\bin\\ffmpeg.exe -i No_QueenBee_Testing_15mins.wav -b:a 64k No_QueenBee_Testing_15mins_64K.mp3

# %%
# !C:\\Python\\libs\\ffmpeg\\bin\\ffmpeg.exe -i QueenBee_Training_45mins.wav -b:a 16k QueenBee_Training_45mins_16K.mp3
# !C:\\Python\\libs\\ffmpeg\\bin\\ffmpeg.exe -i QueenBee_Testing_15mins.wav -b:a 16k QueenBee_Testing_15mins_16K.mp3
# !C:\\Python\\libs\\ffmpeg\\bin\\ffmpeg.exe -i No_QueenBee_Training_45mins.wav -b:a 16k No_QueenBee_Training_45mins_16K.mp3
# !C:\\Python\\libs\\ffmpeg\\bin\\ffmpeg.exe -i No_QueenBee_Testing_15mins.wav -b:a 16k No_QueenBee_Testing_15mins_16K.mp3

# %%
from pydub import AudioSegment

def convert_to_flac(source_path, target_path):
    # Load the source file
    audio = AudioSegment.from_file(source_path)

    # Export as FLAC
    audio.export(target_path, format="flac")

# Path to your original audio file
source_path = "No_QueenBee_Testing_15mins.wav"  # Change this to the path of your audio file
target_path = "No_QueenBee_Testing_15mins.flac"  # Change this to your desired output path

# Convert to FLAC
convert_to_flac(source_path, target_path)

# Path to your original audio file
source_path = "No_QueenBee_Training_45mins.wav"  # Change this to the path of your audio file
target_path = "No_QueenBee_Training_45mins.flac"  # Change this to your desired output path

# Convert to FLAC
convert_to_flac(source_path, target_path)

# Path to your original audio file
source_path = "QueenBee_Testing_15mins.wav"  # Change this to the path of your audio file
target_path = "QueenBee_Testing_15mins.flac"  # Change this to your desired output path

# Convert to FLAC
convert_to_flac(source_path, target_path)

# Path to your original audio file
source_path = "QueenBee_Training_45mins.wav"  # Change this to the path of your audio file
target_path = "QueenBee_Training_45mins.flac"  # Change this to your desired output path

# Convert to FLAC
convert_to_flac(source_path, target_path)

# %%
# !C:\\Python\\libs\\ffmpeg\\bin\\ffmpeg.exe -hide_banner -y -i QueenBee_Training_45mins.wav -vn -c:a mp3 -minrate:a 16k -maxrate:a 16k -b:a 16k -sample_fmt s16p -bufsize 200K -ar 8000 QueenBee_Training_45mins_16K.mp3
# !C:\\Python\\libs\\ffmpeg\\bin\\ffmpeg.exe -hide_banner -y -i QueenBee_Testing_15mins.wav -vn -c:a mp3 -minrate:a 16k -maxrate:a 16k -b:a 16k -sample_fmt s16p -bufsize 200K -ar 8000 QueenBee_Testing_15mins_16K.mp3
# !C:\\Python\\libs\\ffmpeg\\bin\\ffmpeg.exe -hide_banner -y -i No_QueenBee_Training_45mins.wav -vn -c:a mp3 -minrate:a 16k -maxrate:a 16k -b:a 16k -sample_fmt s16p -bufsize 200K -ar 8000 No_QueenBee_Training_45mins_16K.mp3
# !C:\\Python\\libs\\ffmpeg\\bin\\ffmpeg.exe -hide_banner -y -i No_QueenBee_Testing_15mins.wav -vn -c:a mp3 -minrate:a 16k -maxrate:a 16k -b:a 16k -sample_fmt s16p -bufsize 200K -ar 8000 No_QueenBee_Testing_15mins_16K.mp3
# Out:
# [aist#0:0/pcm_s16le @ 00000170a55f5840] Guessed Channel Layout: stereo
# Input #0, wav, from 'QueenBee_Training_45mins.wav':
#   Duration: 00:46:25.76, bitrate: 1411 kb/s
#   Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 44100 Hz, 2 channels, s16, 1411 kb/s
# Stream mapping:
#   Stream #0:0 -> #0:0 (pcm_s16le (native) -> mp3 (libmp3lame))
# Press [q] to stop, [?] for help
# Output #0, mp3, to 'QueenBee_Training_45mins_16K.mp3':
#   Metadata:
#     TSSE            : Lavf60.15.100
#   Stream #0:0: Audio: mp3, 8000 Hz, stereo, s16p, 16 kb/s
#     Metadata:
#       encoder         : Lavc60.30.102 libmp3lame
# size=       0kB time=N/A bitrate=N/A speed=N/A
# size=      89kB time=00:00:45.22 bitrate=  16.1kbits/s speed=90.4x
# size=     181kB time=00:01:32.45 bitrate=  16.0kbits/s speed=92.4x
# size=     256kB time=00:02:16.87 bitrate=  15.3kbits/s speed=91.2x
# size=     256kB time=00:02:59.28 bitrate=  11.7kbits/s speed=89.6x
# size=     256kB time=00:03:45.36 bitrate=   9.3kbits/s speed=90.1x
# size=     512kB time=00:04:30.14 bitrate=  15.5kbits/s speed=  90x
# size=     512kB time=00:05:15.50 bitrate=  13.3kbits/s speed=90.1x
# size=     512kB time=00:05:59.06 bitrate=  11.7kbits/s speed=89.7x
# size=     768kB time=00:06:43.49 bitrate=  15.6kbits/s speed=89.6x
# size=     768kB time=00:07:30.58 bitrate=  14.0kbits/s speed=90.1x
# size=     768kB time=00:08:14.57 bitrate=  12.7kbits/s speed=89.9x
# size=    1024kB time=00:08:59.57 bitrate=  15.5kbits/s speed=89.9x
# size=    1024kB time=00:09:44.78 bitrate=  14.3kbits/s speed=89.9x
# size=    1024kB time=00:10:30.14 bitrate=  13.3kbits/s speed=  90x
# size=    1280kB time=00:11:15.22 bitrate=  15.5kbits/s speed=  90x
# size=    1280kB time=00:12:00.79 bitrate=  14.5kbits/s speed=90.1x
# size=    1280kB time=00:12:44.64 bitrate=  13.7kbits/s speed=89.9x
# size=    1536kB time=00:13:30.22 bitrate=  15.5kbits/s speed=  90x
# size=    1536kB time=00:14:14.21 bitrate=  14.7kbits/s speed=89.9x
# size=    1536kB time=00:14:59.28 bitrate=  14.0kbits/s speed=89.9x
# size=    1792kB time=00:15:43.49 bitrate=  15.6kbits/s speed=89.8x
# size=    1792kB time=00:16:26.69 bitrate=  14.9kbits/s speed=89.7x
# size=    1792kB time=00:17:12.34 bitrate=  14.2kbits/s speed=89.7x
# size=    2048kB time=00:17:58.13 bitrate=  15.6kbits/s speed=89.8x
# size=    2048kB time=00:18:43.06 bitrate=  14.9kbits/s speed=89.8x
# size=    2048kB time=00:19:29.21 bitrate=  14.3kbits/s speed=89.9x
# size=    2304kB time=00:20:13.78 bitrate=  15.6kbits/s speed=89.9x
# size=    2304kB time=00:21:00.29 bitrate=  15.0kbits/s speed=  90x
# size=    2304kB time=00:21:45.43 bitrate=  14.5kbits/s speed=  90x
# size=    2560kB time=00:22:29.86 bitrate=  15.5kbits/s speed=  90x
# size=    2560kB time=00:23:13.92 bitrate=  15.0kbits/s speed=89.9x
# size=    2560kB time=00:23:57.77 bitrate=  14.6kbits/s speed=89.8x
# size=    2816kB time=00:24:40.46 bitrate=  15.6kbits/s speed=89.7x
# size=    2816kB time=00:25:25.68 bitrate=  15.1kbits/s speed=89.7x
# size=    2816kB time=00:26:11.18 bitrate=  14.7kbits/s speed=89.7x
# size=    3072kB time=00:26:56.83 bitrate=  15.6kbits/s speed=89.8x
# size=    3072kB time=00:27:42.19 bitrate=  15.1kbits/s speed=89.8x
# size=    3328kB time=00:28:27.55 bitrate=  16.0kbits/s speed=89.8x
# size=    3328kB time=00:29:12.55 bitrate=  15.6kbits/s speed=89.8x
# size=    3328kB time=00:29:56.90 bitrate=  15.2kbits/s speed=89.8x
# size=    3584kB time=00:30:42.26 bitrate=  15.9kbits/s speed=89.8x
# size=    3584kB time=00:31:27.98 bitrate=  15.6kbits/s speed=89.9x
# size=    3584kB time=00:32:13.99 bitrate=  15.2kbits/s speed=89.9x
# size=    3840kB time=00:32:59.93 bitrate=  15.9kbits/s speed=  90x
# size=    3840kB time=00:33:45.29 bitrate=  15.5kbits/s speed=  90x
# size=    3840kB time=00:34:29.57 bitrate=  15.2kbits/s speed=89.9x
# size=    4096kB time=00:35:15.50 bitrate=  15.9kbits/s speed=  90x
# size=    4096kB time=00:36:01.51 bitrate=  15.5kbits/s speed=  90x
# size=    4096kB time=00:36:47.52 bitrate=  15.2kbits/s speed=90.1x
# size=    4352kB time=00:37:33.67 bitrate=  15.8kbits/s speed=90.1x
# size=    4352kB time=00:38:20.04 bitrate=  15.5kbits/s speed=90.2x
# size=    4352kB time=00:39:06.26 bitrate=  15.2kbits/s speed=90.2x
# size=    4608kB time=00:39:52.56 bitrate=  15.8kbits/s speed=90.2x
# size=    4608kB time=00:40:38.21 bitrate=  15.5kbits/s speed=90.3x
# size=    4608kB time=00:41:24.00 bitrate=  15.2kbits/s speed=90.3x
# size=    4864kB time=00:42:08.93 bitrate=  15.8kbits/s speed=90.3x
# size=    4864kB time=00:42:53.57 bitrate=  15.5kbits/s speed=90.3x
# size=    4864kB time=00:43:39.36 bitrate=  15.2kbits/s speed=90.3x
# size=    5120kB time=00:44:25.66 bitrate=  15.7kbits/s speed=90.3x
# size=    5120kB time=00:45:11.23 bitrate=  15.5kbits/s speed=90.3x
# size=    5376kB time=00:45:56.45 bitrate=  16.0kbits/s speed=90.3x
# [libmp3lame @ 00000170a561e5c0] Trying to remove 576 samples, but the queue is empty
# [out#0/mp3 @ 00000170a55fa3c0] video:0kB audio:5441kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.004684%
# size=    5442kB time=00:46:25.75 bitrate=  16.0kbits/s speed=90.3x
# [aist#0:0/pcm_s16le @ 0000027790495840] Guessed Channel Layout: stereo
# Input #0, wav, from 'QueenBee_Testing_15mins.wav':
#   Duration: 00:15:39.07, bitrate: 1411 kb/s
#   Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 44100 Hz, 2 channels, s16, 1411 kb/s
# Stream mapping:
#   Stream #0:0 -> #0:0 (pcm_s16le (native) -> mp3 (libmp3lame))
# Press [q] to stop, [?] for help
# Output #0, mp3, to 'QueenBee_Testing_15mins_16K.mp3':
#   Metadata:
#     TSSE            : Lavf60.15.100
#   Stream #0:0: Audio: mp3, 8000 Hz, stereo, s16p, 16 kb/s
#     Metadata:
#       encoder         : Lavc60.30.102 libmp3lame
# size=       0kB time=N/A bitrate=N/A speed=N/A
# size=      66kB time=00:00:33.34 bitrate=  16.1kbits/s speed=66.7x
# size=     151kB time=00:01:16.97 bitrate=  16.0kbits/s speed=  77x
# size=     236kB time=00:02:00.31 bitrate=  16.0kbits/s speed=80.2x
# size=     256kB time=00:02:44.81 bitrate=  12.7kbits/s speed=82.4x
# size=     256kB time=00:03:30.10 bitrate=  10.0kbits/s speed=  84x
# size=     256kB time=00:04:15.74 bitrate=   8.2kbits/s speed=85.2x
# size=     512kB time=00:05:00.67 bitrate=  13.9kbits/s speed=85.9x
# size=     512kB time=00:05:45.24 bitrate=  12.1kbits/s speed=86.3x
# size=     512kB time=00:06:29.38 bitrate=  10.8kbits/s speed=86.5x
# size=     768kB time=00:07:14.30 bitrate=  14.5kbits/s speed=86.8x
# size=     768kB time=00:07:59.95 bitrate=  13.1kbits/s speed=87.2x
# size=    1024kB time=00:08:44.88 bitrate=  16.0kbits/s speed=87.4x
# size=    1024kB time=00:09:30.38 bitrate=  14.7kbits/s speed=87.7x
# size=    1024kB time=00:10:15.82 bitrate=  13.6kbits/s speed=87.9x
# size=    1280kB time=00:11:00.24 bitrate=  15.9kbits/s speed=  88x
# size=    1280kB time=00:11:44.66 bitrate=  14.9kbits/s speed=  88x
# size=    1280kB time=00:12:04.18 bitrate=  14.5kbits/s speed=81.7x
# size=    1280kB time=00:12:42.34 bitrate=  13.8kbits/s speed=81.4x
# size=    1536kB time=00:13:22.87 bitrate=  15.7kbits/s speed=81.4x
# size=    1536kB time=00:14:05.57 bitrate=  14.9kbits/s speed=81.6x
# size=    1536kB time=00:14:50.57 bitrate=  14.1kbits/s speed=  82x
# size=    1792kB time=00:15:35.21 bitrate=  15.7kbits/s speed=82.3x
# [out#0/mp3 @ 000002779049a3c0] video:0kB audio:1834kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.013894%
# size=    1835kB time=00:15:39.02 bitrate=  16.0kbits/s speed=82.3x
# [aist#0:0/pcm_s16le @ 000001ed667b5840] Guessed Channel Layout: stereo
# Input #0, wav, from 'No_QueenBee_Training_45mins.wav':
#   Duration: 00:46:10.84, bitrate: 1411 kb/s
#   Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 44100 Hz, 2 channels, s16, 1411 kb/s
# Stream mapping:
#   Stream #0:0 -> #0:0 (pcm_s16le (native) -> mp3 (libmp3lame))
# Press [q] to stop, [?] for help
# Output #0, mp3, to 'No_QueenBee_Training_45mins_16K.mp3':
#   Metadata:
#     TSSE            : Lavf60.15.100
#   Stream #0:0: Audio: mp3, 8000 Hz, stereo, s16p, 16 kb/s
#     Metadata:
#       encoder         : Lavc60.30.102 libmp3lame
# size=       0kB time=N/A bitrate=N/A speed=N/A
# size=      87kB time=00:00:44.35 bitrate=  16.1kbits/s speed=88.7x
# size=     173kB time=00:01:28.20 bitrate=  16.0kbits/s speed=88.2x
# size=     256kB time=00:02:12.41 bitrate=  15.8kbits/s speed=88.3x
# size=     256kB time=00:02:55.46 bitrate=  12.0kbits/s speed=87.7x
# size=     256kB time=00:03:39.89 bitrate=   9.5kbits/s speed=87.9x
# size=     512kB time=00:04:24.46 bitrate=  15.9kbits/s speed=88.1x
# size=     512kB time=00:05:09.67 bitrate=  13.5kbits/s speed=88.4x
# size=     512kB time=00:05:53.66 bitrate=  11.9kbits/s speed=88.4x
# size=     768kB time=00:06:34.78 bitrate=  15.9kbits/s speed=87.7x
# size=     768kB time=00:07:18.48 bitrate=  14.3kbits/s speed=87.7x
# size=     768kB time=00:08:03.26 bitrate=  13.0kbits/s speed=87.8x
# size=    1024kB time=00:08:46.75 bitrate=  15.9kbits/s speed=87.8x
# size=    1024kB time=00:09:32.33 bitrate=  14.7kbits/s speed=  88x
# size=    1024kB time=00:10:17.04 bitrate=  13.6kbits/s speed=88.1x
# size=    1280kB time=00:11:03.12 bitrate=  15.8kbits/s speed=88.4x
# size=    1280kB time=00:11:48.12 bitrate=  14.8kbits/s speed=88.5x
# size=    1280kB time=00:12:32.26 bitrate=  13.9kbits/s speed=88.5x
# size=    1536kB time=00:13:17.26 bitrate=  15.8kbits/s speed=88.5x
# size=    1536kB time=00:14:02.98 bitrate=  14.9kbits/s speed=88.7x
# size=    1536kB time=00:14:47.54 bitrate=  14.2kbits/s speed=88.7x
# size=    1792kB time=00:15:33.41 bitrate=  15.7kbits/s speed=88.9x
# size=    1792kB time=00:16:19.20 bitrate=  15.0kbits/s speed=  89x
# size=    1792kB time=00:17:04.92 bitrate=  14.3kbits/s speed=89.1x
# size=    2048kB time=00:17:50.78 bitrate=  15.7kbits/s speed=89.2x
# size=    2048kB time=00:18:36.07 bitrate=  15.0kbits/s speed=89.2x
# size=    2048kB time=00:19:21.22 bitrate=  14.4kbits/s speed=89.3x
# size=    2304kB time=00:20:04.49 bitrate=  15.7kbits/s speed=89.2x
# size=    2304kB time=00:20:50.35 bitrate=  15.1kbits/s speed=89.3x
# size=    2304kB time=00:21:36.00 bitrate=  14.6kbits/s speed=89.3x
# size=    2560kB time=00:22:21.00 bitrate=  15.6kbits/s speed=89.4x
# size=    2560kB time=00:23:06.58 bitrate=  15.1kbits/s speed=89.4x
# size=    2560kB time=00:23:51.14 bitrate=  14.7kbits/s speed=89.4x
# size=    2816kB time=00:24:36.94 bitrate=  15.6kbits/s speed=89.5x
# size=    2816kB time=00:25:21.36 bitrate=  15.2kbits/s speed=89.5x
# size=    2816kB time=00:26:07.51 bitrate=  14.7kbits/s speed=89.5x
# size=    3072kB time=00:26:52.15 bitrate=  15.6kbits/s speed=89.5x
# size=    3072kB time=00:27:37.30 bitrate=  15.2kbits/s speed=89.5x
# size=    3072kB time=00:28:22.66 bitrate=  14.8kbits/s speed=89.6x
# size=    3328kB time=00:29:02.18 bitrate=  15.6kbits/s speed=89.3x
# size=    3328kB time=00:29:47.90 bitrate=  15.2kbits/s speed=89.4x
# size=    3328kB time=00:30:32.76 bitrate=  14.9kbits/s speed=89.4x
# size=    3584kB time=00:31:17.90 bitrate=  15.6kbits/s speed=89.4x
# size=    3584kB time=00:32:03.26 bitrate=  15.3kbits/s speed=89.4x
# size=    3840kB time=00:32:48.19 bitrate=  16.0kbits/s speed=89.4x
# size=    3840kB time=00:33:33.26 bitrate=  15.6kbits/s speed=89.4x
# size=    3840kB time=00:34:18.62 bitrate=  15.3kbits/s speed=89.5x
# size=    4096kB time=00:35:04.49 bitrate=  15.9kbits/s speed=89.5x
# size=    4096kB time=00:35:48.62 bitrate=  15.6kbits/s speed=89.5x
# size=    4096kB time=00:36:32.47 bitrate=  15.3kbits/s speed=89.4x
# size=    4352kB time=00:37:17.26 bitrate=  15.9kbits/s speed=89.4x
# size=    4352kB time=00:38:02.26 bitrate=  15.6kbits/s speed=89.5x
# size=    4352kB time=00:38:46.68 bitrate=  15.3kbits/s speed=89.4x
# size=    4608kB time=00:39:32.62 bitrate=  15.9kbits/s speed=89.5x
# size=    4608kB time=00:40:18.48 bitrate=  15.6kbits/s speed=89.5x
# size=    4608kB time=00:41:03.26 bitrate=  15.3kbits/s speed=89.5x
# size=    4864kB time=00:41:47.26 bitrate=  15.9kbits/s speed=89.5x
# size=    4864kB time=00:42:32.47 bitrate=  15.6kbits/s speed=89.5x
# size=    4864kB time=00:43:17.83 bitrate=  15.3kbits/s speed=89.5x
# size=    5120kB time=00:44:02.26 bitrate=  15.9kbits/s speed=89.5x
# size=    5120kB time=00:44:47.69 bitrate=  15.6kbits/s speed=89.6x
# size=    5120kB time=00:45:33.26 bitrate=  15.3kbits/s speed=89.6x
# [out#0/mp3 @ 000001ed667ba3c0] video:0kB audio:5412kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.004710%
# size=    5412kB time=00:46:10.78 bitrate=  16.0kbits/s speed=89.6x
# [aist#0:0/pcm_s16le @ 000002163a0b5840] Guessed Channel Layout: stereo
# Input #0, wav, from 'No_QueenBee_Testing_15mins.wav':
#   Duration: 00:15:03.79, bitrate: 1411 kb/s
#   Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 44100 Hz, 2 channels, s16, 1411 kb/s
# Stream mapping:
#   Stream #0:0 -> #0:0 (pcm_s16le (native) -> mp3 (libmp3lame))
# Press [q] to stop, [?] for help
# Output #0, mp3, to 'No_QueenBee_Testing_15mins_16K.mp3':
#   Metadata:
#     TSSE            : Lavf60.15.100
#   Stream #0:0: Audio: mp3, 8000 Hz, stereo, s16p, 16 kb/s
#     Metadata:
#       encoder         : Lavc60.30.102 libmp3lame
# size=       0kB time=N/A bitrate=N/A speed=N/A
# size=      86kB time=00:00:43.99 bitrate=  16.1kbits/s speed=87.9x
# size=     168kB time=00:01:25.61 bitrate=  16.1kbits/s speed=85.6x
# size=     254kB time=00:02:09.60 bitrate=  16.0kbits/s speed=86.4x
# size=     256kB time=00:02:52.58 bitrate=  12.2kbits/s speed=86.3x
# size=     256kB time=00:03:35.64 bitrate=   9.7kbits/s speed=86.2x
# size=     256kB time=00:04:19.78 bitrate=   8.1kbits/s speed=86.6x
# size=     512kB time=00:05:04.49 bitrate=  13.8kbits/s speed=  87x
# size=     512kB time=00:05:49.70 bitrate=  12.0kbits/s speed=87.4x
# size=     768kB time=00:06:34.92 bitrate=  15.9kbits/s speed=87.7x
# size=     768kB time=00:07:19.06 bitrate=  14.3kbits/s speed=87.8x
# size=     768kB time=00:08:04.13 bitrate=  13.0kbits/s speed=  88x
# size=    1024kB time=00:08:47.76 bitrate=  15.9kbits/s speed=87.9x
# size=    1024kB time=00:09:32.62 bitrate=  14.6kbits/s speed=  88x
# size=    1024kB time=00:10:16.68 bitrate=  13.6kbits/s speed=  88x
# size=    1280kB time=00:11:01.54 bitrate=  15.9kbits/s speed=88.1x
# size=    1280kB time=00:11:46.39 bitrate=  14.8kbits/s speed=88.2x
# size=    1280kB time=00:12:31.32 bitrate=  14.0kbits/s speed=88.3x
# size=    1536kB time=00:13:14.59 bitrate=  15.8kbits/s speed=88.2x
# size=    1536kB time=00:13:58.51 bitrate=  15.0kbits/s speed=88.2x
# size=    1536kB time=00:14:43.30 bitrate=  14.2kbits/s speed=88.3x
# [out#0/mp3 @ 000002163a0ba3c0] video:0kB audio:1766kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.014436%
# size=    1766kB time=00:15:03.74 bitrate=  16.0kbits/s speed=88.2x

# %%
# !C:\\Python\\libs\\ffmpeg\\bin\\ffmpeg.exe -hide_banner -y -i audiomass-output.mp3 -vn -c:a mp3 -minrate:a 16k -maxrate:a 16k -b:a 16k -sample_fmt s16p -bufsize 200K -ar 12000 QueenBee_Testing_15mins_16K.mp3
# Out:
# [mp3 @ 000002a33c310a80] Estimating duration from bitrate, this may be inaccurate
# Input #0, mp3, from 'audiomass-output.mp3':
#   Duration: 00:15:03.42, start: 0.000000, bitrate: 128 kb/s
#   Stream #0:0: Audio: mp3, 44100 Hz, stereo, fltp, 128 kb/s
# Stream mapping:
#   Stream #0:0 -> #0:0 (mp3 (mp3float) -> mp3 (libmp3lame))
# Press [q] to stop, [?] for help
# Output #0, mp3, to 'QueenBee_Testing_15mins_16K.mp3':
#   Metadata:
#     TSSE            : Lavf60.15.100
#   Stream #0:0: Audio: mp3, 12000 Hz, stereo, s16p, 16 kb/s
#     Metadata:
#       encoder         : Lavc60.30.102 libmp3lame
# size=       0kB time=N/A bitrate=N/A speed=N/A
# size=      42kB time=00:00:21.41 bitrate=  16.2kbits/s speed=42.8x
# size=     103kB time=00:00:52.70 bitrate=  16.0kbits/s speed=52.7x
# size=     156kB time=00:01:19.44 bitrate=  16.0kbits/s speed=52.9x
# size=     217kB time=00:01:50.83 bitrate=  16.0kbits/s speed=55.4x
# size=     256kB time=00:02:18.38 bitrate=  15.2kbits/s speed=55.3x
# size=     256kB time=00:02:48.81 bitrate=  12.4kbits/s speed=56.2x
# size=     256kB time=00:03:20.25 bitrate=  10.5kbits/s speed=57.2x
# size=     256kB time=00:03:51.21 bitrate=   9.1kbits/s speed=57.8x
# size=     512kB time=00:04:21.98 bitrate=  16.0kbits/s speed=58.2x
# size=     512kB time=00:04:53.28 bitrate=  14.3kbits/s speed=58.6x
# size=     512kB time=00:05:25.25 bitrate=  12.9kbits/s speed=59.1x
# size=     512kB time=00:05:57.07 bitrate=  11.7kbits/s speed=59.5x
# size=     512kB time=00:06:27.31 bitrate=  10.8kbits/s speed=59.6x
# size=     768kB time=00:06:58.32 bitrate=  15.0kbits/s speed=59.7x
# size=     768kB time=00:07:29.81 bitrate=  14.0kbits/s speed=59.9x
# size=     768kB time=00:08:01.15 bitrate=  13.1kbits/s speed=60.1x
# size=     768kB time=00:08:32.25 bitrate=  12.3kbits/s speed=60.2x
# size=    1024kB time=00:09:03.45 bitrate=  15.4kbits/s speed=60.4x
# size=    1024kB time=00:09:35.13 bitrate=  14.6kbits/s speed=60.5x
# size=    1024kB time=00:10:06.38 bitrate=  13.8kbits/s speed=60.6x
# size=    1024kB time=00:10:36.67 bitrate=  13.2kbits/s speed=60.6x
# size=    1280kB time=00:11:08.25 bitrate=  15.7kbits/s speed=60.7x
# size=    1280kB time=00:11:40.03 bitrate=  15.0kbits/s speed=60.8x
# size=    1280kB time=00:12:11.13 bitrate=  14.3kbits/s speed=60.9x
# size=    1280kB time=00:12:42.53 bitrate=  13.8kbits/s speed=  61x
# size=    1536kB time=00:13:14.06 bitrate=  15.8kbits/s speed=61.1x
# size=    1536kB time=00:13:45.98 bitrate=  15.2kbits/s speed=61.2x
# size=    1536kB time=00:14:17.66 bitrate=  14.7kbits/s speed=61.2x
# size=    1536kB time=00:14:49.92 bitrate=  14.1kbits/s speed=61.3x
# [out#0/mp3 @ 000002a33c32af80] video:0kB audio:1765kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.013115%
# size=    1765kB time=00:15:03.41 bitrate=  16.0kbits/s speed=61.4x

# %%
# !C:\\Python\\libs\\ffmpeg\\bin\\ffmpeg.exe -hide_banner -y -i QueenBee_Testing_15mins_64k.mp3 -vn -c:a mp3 -minrate:a 16k -maxrate:a 16k -b:a 16k -sample_fmt s16p -bufsize 200K -ar 8000 QueenBee_Testing_15mins_16K.mp3
# Out:
# Input #0, mp3, from 'QueenBee_Testing_15mins_64k.mp3':
#   Metadata:
#     encoder         : Lavf60.15.100
#   Duration: 00:15:39.10, start: 0.025057, bitrate: 64 kb/s
#   Stream #0:0: Audio: mp3, 44100 Hz, stereo, fltp, 64 kb/s
#     Metadata:
#       encoder         : Lavc60.30
# Stream mapping:
#   Stream #0:0 -> #0:0 (mp3 (mp3float) -> mp3 (libmp3lame))
# Press [q] to stop, [?] for help
# Output #0, mp3, to 'QueenBee_Testing_15mins_16K.mp3':
#   Metadata:
#     TSSE            : Lavf60.15.100
#   Stream #0:0: Audio: mp3, 8000 Hz, stereo, s16p, 16 kb/s
#     Metadata:
#       encoder         : Lavc60.30.102 libmp3lame
# size=       0kB time=N/A bitrate=N/A speed=N/A
# size=      62kB time=00:00:31.54 bitrate=  16.1kbits/s speed=62.5x
# size=     142kB time=00:01:12.65 bitrate=  16.1kbits/s speed=72.3x
# size=     223kB time=00:01:54.05 bitrate=  16.0kbits/s speed=75.8x
# size=     256kB time=00:02:35.38 bitrate=  13.5kbits/s speed=77.5x
# size=     256kB time=00:03:16.78 bitrate=  10.7kbits/s speed=78.6x
# size=     256kB time=00:03:58.10 bitrate=   8.8kbits/s speed=79.2x
# size=     512kB time=00:04:39.36 bitrate=  15.0kbits/s speed=79.7x
# size=     512kB time=00:05:20.76 bitrate=  13.1kbits/s speed=80.1x
# size=     512kB time=00:06:01.80 bitrate=  11.6kbits/s speed=80.3x
# size=     768kB time=00:06:44.14 bitrate=  15.6kbits/s speed=80.7x
# size=     768kB time=00:07:25.68 bitrate=  14.1kbits/s speed=80.9x
# size=     768kB time=00:08:07.80 bitrate=  12.9kbits/s speed=81.2x
# size=    1024kB time=00:08:49.49 bitrate=  15.8kbits/s speed=81.4x
# size=    1024kB time=00:09:30.89 bitrate=  14.7kbits/s speed=81.5x
# size=    1024kB time=00:10:12.29 bitrate=  13.7kbits/s speed=81.6x
# size=    1024kB time=00:10:52.54 bitrate=  12.9kbits/s speed=81.5x
# size=    1280kB time=00:11:33.14 bitrate=  15.1kbits/s speed=81.5x
# size=    1280kB time=00:12:14.54 bitrate=  14.3kbits/s speed=81.6x
# size=    1280kB time=00:12:55.66 bitrate=  13.5kbits/s speed=81.6x
# size=    1536kB time=00:13:37.70 bitrate=  15.4kbits/s speed=81.7x
# size=    1536kB time=00:14:19.54 bitrate=  14.6kbits/s speed=81.8x
# size=    1536kB time=00:15:02.45 bitrate=  13.9kbits/s speed=  82x
# [out#0/mp3 @ 000002173f94c840] video:0kB audio:1834kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.013894%
# size=    1835kB time=00:15:39.02 bitrate=  16.0kbits/s speed=82.1x
