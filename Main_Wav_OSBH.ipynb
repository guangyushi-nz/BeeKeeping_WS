# %% [markdown]
# WAV

# %%
from Main9 import process_audio_files

# Example usage
queen_training_file = "OSBH\\OSBH_Queen_Training_30mins.wav"
no_queen_training_file = "OSBH\\OSBH_NoQueen_Training_30mins.wav"
queen_validation_file = "OSBH\\OSBH_Queen_Testing_10mins.wav"
no_queen_validation_file = "OSBH\\OSBH_NoQueen_Testing_10mins.wav"

process_audio_files(queen_training_file, no_queen_training_file, queen_validation_file, no_queen_validation_file)
# Out:
# Number of Queen Training Segments: 600
# Number of No Queen Training Segments: 600
#
# Average Accuracy across 10 folds: 100.00%
#
# Number of Queen Testing Segments: 200
# Number of No Queen Testing Segments: 144
#
# Accuracy of MFCC Features on testing Data: 99.71%
#
# Confusion Matrix on Testing Data:
#
# True Positives (TP): 200
# True Negatives (TN): 143
# False Positives (FP): 1
# False Negatives (FN): 0
#
# Classification Report on testing Data:
#                precision    recall  f1-score   support
#
#          0.0       1.00      0.99      1.00       144
#          1.0       1.00      1.00      1.00       200
#
#     accuracy                           1.00       344
#    macro avg       1.00      1.00      1.00       344
# weighted avg       1.00      1.00      1.00       344

# %% [markdown]
# MP3 - 64K

# %%
from Main9 import process_audio_files

# Example usage
queen_training_file = "OSBH\OSBH_Queen_Training_30mins_64K.mp3"
no_queen_training_file = "OSBH\OSBH_NoQueen_Training_30mins_64K.mp3"
queen_validation_file = "OSBH\OSBH_Queen_Testing_10mins_64K.mp3"
no_queen_validation_file = "OSBH\OSBH_NoQueen_Testing_10mins_64K.mp3"

process_audio_files(queen_training_file, no_queen_training_file, queen_validation_file, no_queen_validation_file)
# Out:
# Number of Queen Training Segments: 600
# Number of No Queen Training Segments: 600
#
# Average Accuracy across 10 folds: 99.92%
#
# Number of Queen Testing Segments: 200
# Number of No Queen Testing Segments: 144
#
# Accuracy of MFCC Features on testing Data: 99.71%
#
# Confusion Matrix on Testing Data:
#
# True Positives (TP): 200
# True Negatives (TN): 143
# False Positives (FP): 1
# False Negatives (FN): 0
#
# Classification Report on testing Data:
#                precision    recall  f1-score   support
#
#          0.0       1.00      0.99      1.00       144
#          1.0       1.00      1.00      1.00       200
#
#     accuracy                           1.00       344
#    macro avg       1.00      1.00      1.00       344
# weighted avg       1.00      1.00      1.00       344

# %% [markdown]
# MP3 - 16K

# %%
from Main9 import process_audio_files

# Example usage
queen_training_file = "OSBH\OSBH_Queen_Training_30mins_16K.mp3"
no_queen_training_file = "OSBH\OSBH_NoQueen_Training_30mins_16K.mp3"
queen_validation_file = "OSBH\OSBH_Queen_Testing_10mins_16K.mp3"
no_queen_validation_file = "OSBH\OSBH_NoQueen_Testing_10mins_16K.mp3"

process_audio_files(queen_training_file, no_queen_training_file, queen_validation_file, no_queen_validation_file)
# Out:
# Number of Queen Training Segments: 600
# Number of No Queen Training Segments: 600
#
# Average Accuracy across 10 folds: 99.83%
#
# Number of Queen Testing Segments: 200
# Number of No Queen Testing Segments: 144
#
# Accuracy of MFCC Features on testing Data: 99.42%
#
# Confusion Matrix on Testing Data:
#
# True Positives (TP): 199
# True Negatives (TN): 143
# False Positives (FP): 1
# False Negatives (FN): 1
#
# Classification Report on testing Data:
#                precision    recall  f1-score   support
#
#          0.0       0.99      0.99      0.99       144
#          1.0       0.99      0.99      0.99       200
#
#     accuracy                           0.99       344
#    macro avg       0.99      0.99      0.99       344
# weighted avg       0.99      0.99      0.99       344

# %%
# Example usage
queen_training_file = "OSBH\OSBH_Queen_Training_30mins.flac"
no_queen_training_file = "OSBH\OSBH_NoQueen_Training_30mins.flac"
queen_validation_file = "OSBH\OSBH_Queen_Testing_10mins.flac"
no_queen_validation_file = "OSBH\OSBH_NoQueen_Testing_10mins.flac"

process_audio_files(queen_training_file, no_queen_training_file, queen_validation_file, no_queen_validation_file)
# Out:
# Number of Queen Training Segments: 600
# Number of No Queen Training Segments: 600
#
# Average Accuracy across 10 folds: 100.00%
#
# Number of Queen Testing Segments: 200
# Number of No Queen Testing Segments: 144
#
# Accuracy of MFCC Features on testing Data: 99.71%
#
# Confusion Matrix on Testing Data:
#
# True Positives (TP): 200
# True Negatives (TN): 143
# False Positives (FP): 1
# False Negatives (FN): 0
#
# Classification Report on testing Data:
#                precision    recall  f1-score   support
#
#          0.0       1.00      0.99      1.00       144
#          1.0       1.00      1.00      1.00       200
#
#     accuracy                           1.00       344
#    macro avg       1.00      1.00      1.00       344
# weighted avg       1.00      1.00      1.00       344

# %%
from scipy.signal import get_window
import IPython.display as ipd
import soundfile as sf
# create a mfcc and visualize 
import streamlit as st

import numpy as np
import librosa
import librosa.display
import matplotlib.pyplot as plt

def visualize_mel_spectrogram(audio_file, title):
    # Load audio file
    audio_data, sampling_rate = librosa.load(audio_file, sr=None)
    
    # Calculate Mel spectrogram
    mel_spectrogram = librosa.feature.melspectrogram(y=audio_data, sr=sampling_rate)
    log_mel_spectrogram = librosa.power_to_db(mel_spectrogram, ref=np.max)

    # Plot Mel spectrogram
    plt.figure(figsize=(6, 4))
    librosa.display.specshow(log_mel_spectrogram, sr=sampling_rate, x_axis='time', y_axis='mel', cmap='viridis')
    plt.colorbar(label='dB')
    plt.title(title)
    plt.tight_layout()
    plt.show()

# File paths
queen_wav_sample = "QueenBee_Testing_15mins.wav"
queen_mp3_64K_sample = "QueenBee_Testing_15mins_64K.mp3"
queen_mp3_16K_sample = "QueenBee_Testing_15mins_16K.mp3"
queen_flac_sample = "QueenBee_Testing_15mins.flac"

# Visualize Mel spectrogram for each audio file
visualize_mel_spectrogram(queen_wav_sample, 'Mel Spectrogram of QueenBee_Testing_15mins.wav')
visualize_mel_spectrogram(queen_mp3_64K_sample, 'Mel Spectrogram of QueenBee_Testing_15mins_64K.mp3')
visualize_mel_spectrogram(queen_mp3_16K_sample, 'Mel Spectrogram of QueenBee_Testing_15mins_16K.mp3')
visualize_mel_spectrogram(queen_flac_sample, 'Mel Spectrogram of QueenBee_Testing_15mins.flac')
# Out:
# C:\Users\hippo\AppData\Local\Temp\ipykernel_11328\1638994766.py:14: UserWarning: PySoundFile failed. Trying audioread instead.
#   audio_data, sampling_rate = librosa.load(audio_file, sr=None)
# c:\Python\Lib\site-packages\librosa\core\audio.py:184: FutureWarning: librosa.core.audio.__audioread_load
# 	Deprecated as of librosa version 0.10.0.
# 	It will be removed in librosa version 1.0.
#   y, sr_native = __audioread_load(path, offset, duration, dtype)
# ---------------------------------------------------------------------------
# LibsndfileError                           Traceback (most recent call last)
# File c:\Python\Lib\site-packages\librosa\core\audio.py:176, in load(path, sr, mono, offset, duration, dtype, res_type)
#     175 try:
# --> 176     y, sr_native = __soundfile_load(path, offset, duration, dtype)
#     178 except sf.SoundFileRuntimeError as exc:
#     179     # If soundfile failed, try audioread instead
#
# File c:\Python\Lib\site-packages\librosa\core\audio.py:209, in __soundfile_load(path, offset, duration, dtype)
#     207 else:
#     208     # Otherwise, create the soundfile object
# --> 209     context = sf.SoundFile(path)
#     211 with context as sf_desc:
#
# File c:\Python\Lib\site-packages\soundfile.py:658, in SoundFile.__init__(self, file, mode, samplerate, channels, subtype, endian, format, closefd)
#     656 self._info = _create_info_struct(file, mode, samplerate, channels,
#     657                                  format, subtype, endian)
# --> 658 self._file = self._open(file, mode_int, closefd)
#     659 if set(mode).issuperset('r+') and self.seekable():
#     660     # Move write position to 0 (like in Python file objects)
#
# File c:\Python\Lib\site-packages\soundfile.py:1216, in SoundFile._open(self, file, mode_int, closefd)
#    1215     err = _snd.sf_error(file_ptr)
# -> 1216     raise LibsndfileError(err, prefix="Error opening {0!r}: ".format(self.name))
#    1217 if mode_int == _snd.SFM_WRITE:
#    1218     # Due to a bug in libsndfile version <= 1.0.25, frames != 0
#    1219     # when opening a named pipe in SFM_WRITE mode.
#    1220     # See http://github.com/erikd/libsndfile/issues/77.
#
# LibsndfileError: Error opening 'QueenBee_Testing_15mins.wav': System error.
#
# During handling of the above exception, another exception occurred:
#
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[5], line 35
#      32 queen_flac_sample = "QueenBee_Testing_15mins.flac"
#      34 # Visualize Mel spectrogram for each audio file
# ---> 35 visualize_mel_spectrogram(queen_wav_sample, 'Mel Spectrogram of QueenBee_Testing_15mins.wav')
#      36 visualize_mel_spectrogram(queen_mp3_64K_sample, 'Mel Spectrogram of QueenBee_Testing_15mins_64K.mp3')
#      37 visualize_mel_spectrogram(queen_mp3_16K_sample, 'Mel Spectrogram of QueenBee_Testing_15mins_16K.mp3')
#
# Cell In[5], line 14, in visualize_mel_spectrogram(audio_file, title)
#      12 def visualize_mel_spectrogram(audio_file, title):
#      13     # Load audio file
# ---> 14     audio_data, sampling_rate = librosa.load(audio_file, sr=None)
#      16     # Calculate Mel spectrogram
#      17     mel_spectrogram = librosa.feature.melspectrogram(y=audio_data, sr=sampling_rate)
#
# File c:\Python\Lib\site-packages\librosa\core\audio.py:184, in load(path, sr, mono, offset, duration, dtype, res_type)
#     180 if isinstance(path, (str, pathlib.PurePath)):
#     181     warnings.warn(
#     182         "PySoundFile failed. Trying audioread instead.", stacklevel=2
#     183     )
# --> 184     y, sr_native = __audioread_load(path, offset, duration, dtype)
#     185 else:
#     186     raise exc
#
# File ~\AppData\Roaming\Python\Python311\site-packages\decorator.py:232, in decorate.<locals>.fun(*args, **kw)
#     230 if not kwsyntax:
#     231     args, kw = fix(args, kw, sig)
# --> 232 return caller(func, *(extras + args), **kw)
#
# File c:\Python\Lib\site-packages\librosa\util\decorators.py:60, in deprecated.<locals>.__wrapper(func, *args, **kwargs)
#      51 """Warn the user, and then proceed."""
#      52 warnings.warn(
#      53     "{:s}.{:s}\n\tDeprecated as of librosa version {:s}."
#      54     "\n\tIt will be removed in librosa version {:s}.".format(
#    (...)
#      58     stacklevel=3,  # Would be 2, but the decorator adds a level
#      59 )
# ---> 60 return func(*args, **kwargs)
#
# File c:\Python\Lib\site-packages\librosa\core\audio.py:241, in __audioread_load(path, offset, duration, dtype)
#     238     reader = path
#     239 else:
#     240     # If the input was not an audioread object, try to open it
# --> 241     reader = audioread.audio_open(path)
#     243 with reader as input_file:
#     244     sr_native = input_file.samplerate
#
# File c:\Python\Lib\site-packages\audioread\__init__.py:127, in audio_open(path, backends)
#     125 for BackendClass in backends:
#     126     try:
# --> 127         return BackendClass(path)
#     128     except DecodeError:
#     129         pass
#
# File c:\Python\Lib\site-packages\audioread\rawread.py:59, in RawAudioFile.__init__(self, filename)
#      58 def __init__(self, filename):
# ---> 59     self._fh = open(filename, 'rb')
#      61     try:
#      62         self._file = aifc.open(self._fh)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'QueenBee_Testing_15mins.wav'
